# %%
import sys
sys.path.append("..")
# %load_ext autoreload
# %autoreload

# %%
from utils.wrapper import ArgWrapper

# %%
from main_lb_medfilter_val_bc import run
args= ArgWrapper(
    exp='medfilter_val_bc', 
    net='ModifiedXception',
    batch_size=32,
    ckpt_prefix='Run01',
    device='4',
    nb_class=10,
    l2=0,
    init_lr=0.001,
    lr_factor=0.5,
    lr_patience=3,
    optimizer='adam',
    plot=True,
    run_epochs=80,
    seed=0,
    decay=1,
    drop_rate=0.3,
    mix_alpha=-1.0,
    continue_run=False,
    is_divide_variance=False
)

# %%
run(args)
# Out:
# [CheckPoint:]acc not improved on 0.661
# [CheckPoint:]saved model to /data/songhongwei/proj/dcase19_task1_hitsplab/ckpt/medfilter_val_bc/Run01,ModifiedXception,Epoch_79,acc_0.653808.tar

# %%
args = ArgWrapper({
    'acc_log_file': 'submissions/acc/run.acc',
    'batch_size': 64,
    'ckpt_file': 'ckpt/medfilter_val_bc/Run01,ModifiedXception,Epoch_31,acc_0.661186.tar',
    'decay': 1.0,
    'device': '4',
    'drop_rate': 0.3,
    'l2': 0,
    'method': 'medfilter',
    'model': 'single',
    'model2_is_divide_variance': False,
    'nb_class': 10
})

# %%
from class_wise_accuracy import print_accuracy
print_accuracy(args)
# Out:
# {'acc_log_file': 'submissions/acc/run.acc',
#  'batch_size': 64,
#  'ckpt_file': 'ckpt/medfilter_val_bc/Run01,ModifiedXception,Epoch_31,acc_0.661186.tar',
#  'decay': 1.0,
#  'device': '4',
#  'drop_rate': 0.3,
#  'l2': 0,
#  'method': 'medfilter',
#  'model': 'single',
#  'model2_is_divide_variance': False,
#  'nb_class': 10}
# 16560it [00:00, 227840.64it/s]
# [LOGGING]: Loading test a of shape:  (4185, 128, 430)
# 16560it [00:00, 467804.05it/s]
# [LOGGING] Mean subtracted using device abc
# [LOGGING]: Loading test b of shape:  (540, 128, 430)
# 16560it [00:00, 332935.52it/s]
# [LOGGING] Mean subtracted using device abc
# [LOGGING]: Loading test c of shape:  (540, 128, 430)
# [LOGGING] Mean subtracted using device abc
# device_A:
# device_A Validation set average accuracy: 0.716
# device_A Validation set class-wise accuracy:
# airport               : 0.691
# bus                   : 0.781
# metro                 : 0.732
# metro_station         : 0.717
# park                  : 0.842
# public_square         : 0.579
# shopping_mall         : 0.678
# street_pedestrian     : 0.524
# street_traffic        : 0.868
# tram                  : 0.757
# device_B:
# device_B Validation set average accuracy: 0.596
# device_B Validation set class-wise accuracy:
# airport               : 0.593
# bus                   : 0.667
# metro                 : 0.741
# metro_station         : 0.574
# park                  : 0.741
# public_square         : 0.241
# shopping_mall         : 0.648
# street_pedestrian     : 0.407
# street_traffic        : 0.815
# tram                  : 0.537
# device_C:
# device_C Validation set average accuracy: 0.617
# device_C Validation set class-wise accuracy:
# airport               : 0.667
# bus                   : 0.704
# metro                 : 0.556
# metro_station         : 0.463
# park                  : 0.907
# public_square         : 0.407
# shopping_mall         : 0.611
# street_pedestrian     : 0.389
# street_traffic        : 0.796
# tram                  : 0.667
# Average (B, C):
# Average (B, C) Validation set average accuracy: 0.606
# Average (B, C) Validation set class-wise accuracy:
# airport               : 0.630
# bus                   : 0.685
# metro                 : 0.648
# metro_station         : 0.519
# park                  : 0.824
# public_square         : 0.324
# shopping_mall         : 0.630
# street_pedestrian     : 0.398
# street_traffic        : 0.806
# tram                  : 0.602
