# %%
import sys
sys.path.append("..")
# %load_ext autoreload
# %autoreload

# %%
from utils.wrapper import ArgWrapper

# %%
from main_lb_meansub import run
args= ArgWrapper(
    exp='meansub_mixup', 
    net='ModifiedXception',
    batch_size=32,
    ckpt_prefix='Run01',
    device='5',
    nb_class=10,
    l2=0,
    init_lr=0.001,
    lr_factor=0.5,
    lr_patience=3,
    optimizer='adam',
    plot=True,
    run_epochs=80,
    seed=0,
    decay=1,
    drop_rate=0.3,
    mix_alpha=0.3,
    continue_run=False,
    is_divide_variance=False
)

# %%
run(args)
# Out:
# [CheckPoint:]acc not improved on 0.704
# [CheckPoint:]saved model to /data/songhongwei/proj/dcase19_task1_hitsplab/ckpt/meansub_mixup/Run01,ModifiedXception,Epoch_79,acc_0.697246.tar

# %%
args = ArgWrapper({
    'acc_log_file': 'submissions/acc/run.acc',
    'batch_size': 64,
    'ckpt_file': 'ckpt/meansub_mixup/Run01,ModifiedXception,Epoch_42,acc_0.703894.tar',
    'decay': 1.0,
    'device': '5',
    'drop_rate': 0.3,
    'l2': 0,
    'method': 'meansub',
    'model': 'single',
    'model3_is_divide_variance': False,
    'nb_class': 10
})

# %%
from class_wise_accuracy import print_accuracy
print_accuracy(args)
# Out:
# {'acc_log_file': 'submissions/acc/run.acc',
#  'batch_size': 64,
#  'ckpt_file': 'ckpt/meansub_mixup/Run01,ModifiedXception,Epoch_42,acc_0.703894.tar',
#  'decay': 1.0,
#  'device': '5',
#  'drop_rate': 0.3,
#  'l2': 0,
#  'method': 'meansub',
#  'model': 'single',
#  'model3_is_divide_variance': False,
#  'nb_class': 10}
# 16560it [00:00, 297560.12it/s]
# [LOGGING]: Loading test a of shape:  (4185, 128, 430)
# 16560it [00:00, 504830.97it/s]
# [LOGGING] Mean subtracted using device abc
# [LOGGING]: Loading test b of shape:  (540, 128, 430)
# 16560it [00:00, 371753.47it/s]
# [LOGGING] Mean subtracted using device abc
# [LOGGING]: Loading test c of shape:  (540, 128, 430)
# [LOGGING] Mean subtracted using device abc
# device_A:
# device_A Validation set average accuracy: 0.710
# device_A Validation set class-wise accuracy:
# airport               : 0.625
# bus                   : 0.843
# metro                 : 0.725
# metro_station         : 0.653
# park                  : 0.865
# public_square         : 0.610
# shopping_mall         : 0.624
# street_pedestrian     : 0.590
# street_traffic        : 0.905
# tram                  : 0.686
# device_B:
# device_B Validation set average accuracy: 0.669
# device_B Validation set class-wise accuracy:
# airport               : 0.611
# bus                   : 0.796
# metro                 : 0.667
# metro_station         : 0.630
# park                  : 0.704
# public_square         : 0.537
# shopping_mall         : 0.722
# street_pedestrian     : 0.389
# street_traffic        : 0.870
# tram                  : 0.759
# device_C:
# device_C Validation set average accuracy: 0.691
# device_C Validation set class-wise accuracy:
# airport               : 0.500
# bus                   : 0.889
# metro                 : 0.741
# metro_station         : 0.722
# park                  : 0.593
# public_square         : 0.537
# shopping_mall         : 0.741
# street_pedestrian     : 0.593
# street_traffic        : 0.944
# tram                  : 0.648
# Average (B, C):
# Average (B, C) Validation set average accuracy: 0.680
# Average (B, C) Validation set class-wise accuracy:
# airport               : 0.556
# bus                   : 0.843
# metro                 : 0.704
# metro_station         : 0.676
# park                  : 0.648
# public_square         : 0.537
# shopping_mall         : 0.731
# street_pedestrian     : 0.491
# street_traffic        : 0.907
# tram                  : 0.704
