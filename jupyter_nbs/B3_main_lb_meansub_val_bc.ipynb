# %%
import sys
sys.path.append("..")
# %load_ext autoreload
# %autoreload

# %%
from utils.wrapper import ArgWrapper

# %%
from main_lb_meansub_val_bc import run
args= ArgWrapper(
    exp='meansub_val_bc', 
    net='ModifiedXception',
    batch_size=32,
    ckpt_prefix='Run01',
    device='3',
    nb_class=10,
    l2=0,
    init_lr=0.001,
    lr_factor=0.5,
    lr_patience=3,
    optimizer='adam',
    plot=True,
    run_epochs=80,
    seed=0,
    decay=1,
    drop_rate=0.3,
    mix_alpha=-1.0,
    continue_run=False,
    is_divide_variance=False
)

# %%
run(args)
# Out:
# [CheckPoint:]acc not improved on 0.652
# [CheckPoint:]saved model to /data/songhongwei/proj/dcase19_task1_hitsplab/ckpt/meansub_val_bc/Run01,ModifiedXception,Epoch_79,acc_0.643892.tar

# %%
args = ArgWrapper({
    'acc_log_file': 'submissions/acc/run.acc',
    'batch_size': 64,
    'ckpt_file': 'ckpt/meansub_val_bc/Run01,ModifiedXception,Epoch_9,acc_0.652494.tar',
    'decay': 1.0,
    'device': '3',
    'drop_rate': 0.3,
    'l2': 0,
    'method': 'meansub',
    'model': 'single',
    'model3_is_divide_variance': False,
    'nb_class': 10
})

# %%
from class_wise_accuracy import print_accuracy
print_accuracy(args)
# Out:
# {'acc_log_file': 'submissions/acc/run.acc',
#  'batch_size': 64,
#  'ckpt_file': 'ckpt/meansub_val_bc/Run01,ModifiedXception,Epoch_9,acc_0.652494.tar',
#  'decay': 1.0,
#  'device': '3',
#  'drop_rate': 0.3,
#  'l2': 0,
#  'method': 'meansub',
#  'model': 'single',
#  'model3_is_divide_variance': False,
#  'nb_class': 10}
# 16560it [00:00, 331757.16it/s]
# [LOGGING]: Loading test a of shape:  (4185, 128, 430)
# 16560it [00:00, 506594.66it/s]
# [LOGGING] Mean subtracted using device abc
# [LOGGING]: Loading test b of shape:  (540, 128, 430)
# 16560it [00:00, 282077.66it/s]
# [LOGGING] Mean subtracted using device abc
# [LOGGING]: Loading test c of shape:  (540, 128, 430)
# [LOGGING] Mean subtracted using device abc
# device_A:
# device_A Validation set average accuracy: 0.678
# device_A Validation set class-wise accuracy:
# airport               : 0.449
# bus                   : 0.829
# metro                 : 0.691
# metro_station         : 0.598
# park                  : 0.865
# public_square         : 0.506
# shopping_mall         : 0.671
# street_pedestrian     : 0.664
# street_traffic        : 0.856
# tram                  : 0.667
# device_B:
# device_B Validation set average accuracy: 0.639
# device_B Validation set class-wise accuracy:
# airport               : 0.426
# bus                   : 0.778
# metro                 : 0.556
# metro_station         : 0.611
# park                  : 0.704
# public_square         : 0.407
# shopping_mall         : 0.796
# street_pedestrian     : 0.611
# street_traffic        : 0.852
# tram                  : 0.648
# device_C:
# device_C Validation set average accuracy: 0.615
# device_C Validation set class-wise accuracy:
# airport               : 0.259
# bus                   : 0.815
# metro                 : 0.556
# metro_station         : 0.611
# park                  : 0.537
# public_square         : 0.370
# shopping_mall         : 0.833
# street_pedestrian     : 0.722
# street_traffic        : 0.907
# tram                  : 0.537
# Average (B, C):
# Average (B, C) Validation set average accuracy: 0.627
# Average (B, C) Validation set class-wise accuracy:
# airport               : 0.343
# bus                   : 0.796
# metro                 : 0.556
# metro_station         : 0.611
# park                  : 0.620
# public_square         : 0.389
# shopping_mall         : 0.815
# street_pedestrian     : 0.667
# street_traffic        : 0.880
# tram                  : 0.593
