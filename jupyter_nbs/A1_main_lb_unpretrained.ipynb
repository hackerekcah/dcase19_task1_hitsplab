# %%
import sys
sys.path.append("..")
# %load_ext autoreload
# %autoreload

# %%
from utils.wrapper import ArgWrapper

# %%
from main_lb_unpretrained import run
args= ArgWrapper(
    exp='unpretrained', 
    net='ModifiedXception',
    batch_size=32,
    ckpt_prefix='Run01',
    device='3',
    nb_class=10,
    l2=0,
    init_lr=0.001,
    lr_factor=0.5,
    lr_patience=3,
    optimizer='adam',
    plot=True,
    run_epochs=80,
    seed=0,
    decay=1,
    drop_rate=0.3,
    mix_alpha=-1.0,
    continue_run=False,
    is_divide_variance=True
)

# %%
run(args)
# Out:
# [CheckPoint:]acc not improved on 0.652
# [CheckPoint:]saved model to /data/songhongwei/proj/dcase19_task1_hitsplab/ckpt/unpretrained/Run01,ModifiedXception,Epoch_79,acc_0.643875.tar

# %%
args = ArgWrapper({
    'acc_log_file': 'submissions/acc/run.acc',
    'batch_size': 64,
    'ckpt_file': 'ckpt/unpretrained/Run01,ModifiedXception,Epoch_66,acc_0.652232.tar',
    'decay': 1.0,
    'device': '3',
    'drop_rate': 0.3,
    'l2': 0,
    'method': 'normal',
    'model': 'single',
    'model1_is_divide_variance': True,
    'nb_class': 10
})

# %%
from class_wise_accuracy import print_accuracy
print_accuracy(args)
# Out:
# {'acc_log_file': 'submissions/acc/run.acc',
#  'batch_size': 64,
#  'ckpt_file': 'ckpt/unpretrained/Run01,ModifiedXception,Epoch_66,acc_0.652232.tar',
#  'decay': 1.0,
#  'device': '3',
#  'drop_rate': 0.3,
#  'l2': 0,
#  'method': 'normal',
#  'model': 'single',
#  'model1_is_divide_variance': True,
#  'nb_class': 10}
# 16560it [00:00, 514642.34it/s]
# [LOGGING]: Loading test a of shape:  (4185, 128, 430)
# 16560it [00:00, 506144.29it/s]
# [LOGGING] Normalize using device abc
# 0it [00:00, ?it/s]
# [LOGGING]: Loading test b of shape:  (540, 128, 430)
# [LOGGING] Normalize using device abc
# 16560it [00:00, 428476.00it/s]
# [LOGGING]: Loading test c of shape:  (540, 128, 430)
# [LOGGING] Normalize using device abc
# device_A:
# device_A Validation set average accuracy: 0.692
# device_A Validation set class-wise accuracy:
# airport               : 0.810
# bus                   : 0.677
# metro                 : 0.607
# metro_station         : 0.694
# park                  : 0.813
# public_square         : 0.530
# shopping_mall         : 0.592
# street_pedestrian     : 0.653
# street_traffic        : 0.891
# tram                  : 0.672
# device_B:
# device_B Validation set average accuracy: 0.457
# device_B Validation set class-wise accuracy:
# airport               : 0.259
# bus                   : 0.370
# metro                 : 0.444
# metro_station         : 0.519
# park                  : 0.704
# public_square         : 0.167
# shopping_mall         : 0.481
# street_pedestrian     : 0.630
# street_traffic        : 0.852
# tram                  : 0.148
# device_C:
# device_C Validation set average accuracy: 0.535
# device_C Validation set class-wise accuracy:
# airport               : 0.556
# bus                   : 0.593
# metro                 : 0.426
# metro_station         : 0.593
# park                  : 0.722
# public_square         : 0.241
# shopping_mall         : 0.463
# street_pedestrian     : 0.463
# street_traffic        : 0.870
# tram                  : 0.426
# Average (B, C):
# Average (B, C) Validation set average accuracy: 0.496
# Average (B, C) Validation set class-wise accuracy:
# airport               : 0.407
# bus                   : 0.481
# metro                 : 0.435
# metro_station         : 0.556
# park                  : 0.713
# public_square         : 0.204
# shopping_mall         : 0.472
# street_pedestrian     : 0.546
# street_traffic        : 0.861
# tram                  : 0.287
