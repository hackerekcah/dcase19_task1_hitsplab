# %%
import sys
sys.path.append("..")
# %load_ext autoreload
# %autoreload

# %%
from utils.wrapper import ArgWrapper

# %%
from main_lb_meansub import run
args= ArgWrapper(
    exp='meansub', 
    net='ModifiedXception',
    batch_size=32,
    ckpt_prefix='Run01',
    device='4',
    nb_class=10,
    l2=0,
    init_lr=0.001,
    lr_factor=0.5,
    lr_patience=3,
    optimizer='adam',
    plot=True,
    run_epochs=80,
    seed=0,
    decay=1,
    drop_rate=0.3,
    mix_alpha=-1.0,
    continue_run=False,
    is_divide_variance=False
)

# %%
run(args)
# Out:
# [CheckPoint:]acc not improved on 0.668
# [CheckPoint:]saved model to /data/songhongwei/proj/dcase19_task1_hitsplab/ckpt/meansub/Run01,ModifiedXception,Epoch_79,acc_0.662488.tar

# %%
args = ArgWrapper({
    'acc_log_file': 'submissions/acc/run.acc',
    'batch_size': 64,
    'ckpt_file': 'ckpt/meansub/Run01,ModifiedXception,Epoch_22,acc_0.667806.tar',
    'decay': 1.0,
    'device': '1',
    'drop_rate': 0.3,
    'l2': 0,
    'method': 'meansub',
    'model': 'single',
    'model3_is_divide_variance': False,
    'nb_class': 10
})

# %%
from class_wise_accuracy import print_accuracy
print_accuracy(args)
# Out:
# {'acc_log_file': 'submissions/acc/run.acc',
#  'batch_size': 64,
#  'ckpt_file': 'ckpt/meansub/Run01,ModifiedXception,Epoch_22,acc_0.667806.tar',
#  'decay': 1.0,
#  'device': '1',
#  'drop_rate': 0.3,
#  'l2': 0,
#  'method': 'meansub',
#  'model': 'single',
#  'model3_is_divide_variance': False,
#  'nb_class': 10}
# 16560it [00:00, 194940.46it/s]
# [LOGGING]: Loading test a of shape:  (4185, 128, 430)
# 16560it [00:00, 230078.39it/s]
# [LOGGING] Mean subtracted using device abc
# 16560it [00:00, 415391.87it/s]
# [LOGGING]: Loading test b of shape:  (540, 128, 430)
# [LOGGING] Mean subtracted using device abc
# [LOGGING]: Loading test c of shape:  (540, 128, 430)
# [LOGGING] Mean subtracted using device abc
# device_A:
# device_A Validation set average accuracy: 0.677
# device_A Validation set class-wise accuracy:
# airport               : 0.515
# bus                   : 0.843
# metro                 : 0.748
# metro_station         : 0.671
# park                  : 0.795
# public_square         : 0.550
# shopping_mall         : 0.615
# street_pedestrian     : 0.529
# street_traffic        : 0.878
# tram                  : 0.642
# device_B:
# device_B Validation set average accuracy: 0.652
# device_B Validation set class-wise accuracy:
# airport               : 0.500
# bus                   : 0.852
# metro                 : 0.759
# metro_station         : 0.722
# park                  : 0.796
# public_square         : 0.333
# shopping_mall         : 0.685
# street_pedestrian     : 0.333
# street_traffic        : 0.889
# tram                  : 0.648
# device_C:
# device_C Validation set average accuracy: 0.611
# device_C Validation set class-wise accuracy:
# airport               : 0.407
# bus                   : 0.796
# metro                 : 0.722
# metro_station         : 0.648
# park                  : 0.500
# public_square         : 0.426
# shopping_mall         : 0.667
# street_pedestrian     : 0.574
# street_traffic        : 0.870
# tram                  : 0.500
# Average (B, C):
# Average (B, C) Validation set average accuracy: 0.631
# Average (B, C) Validation set class-wise accuracy:
# airport               : 0.454
# bus                   : 0.824
# metro                 : 0.741
# metro_station         : 0.685
# park                  : 0.648
# public_square         : 0.380
# shopping_mall         : 0.676
# street_pedestrian     : 0.454
# street_traffic        : 0.880
# tram                  : 0.574
