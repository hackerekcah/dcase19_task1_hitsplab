# %%
import sys
sys.path.append("..")
# %load_ext autoreload
# %autoreload

# %%
from utils.wrapper import ArgWrapper

# %%
from main_lb_val_bc import run
args= ArgWrapper(
    exp='normal_mixup_val_bc', 
    net='ModifiedXception',
    batch_size=32,
    ckpt_prefix='Run01',
    device='5',
    nb_class=10,
    l2=0,
    init_lr=0.001,
    lr_factor=0.5,
    lr_patience=3,
    optimizer='adam',
    plot=True,
    run_epochs=80,
    seed=0,
    decay=1,
    drop_rate=0.3,
    mix_alpha=0.3,
    continue_run=False,
    is_divide_variance=True
)

# %%
run(args)
# Out:
# [CheckPoint:]acc not improved on 0.712
# [CheckPoint:]saved model to /data/songhongwei/proj/dcase19_task1_hitsplab/ckpt/normal_mixup_val_bc/Run01,ModifiedXception,Epoch_79,acc_0.699149.tar

# %%
from class_wise_accuracy import print_accuracy

# %%
args = ArgWrapper({
    'acc_log_file': 'submissions/acc/run.acc',
    'batch_size': 64,
    'ckpt_file': 'ckpt/normal_mixup_val_bc/Run01,ModifiedXception,Epoch_33,acc_0.711634.tar',
    'decay': 1.0,
    'device': '3',
    'drop_rate': 0.3,
    'l2': 0,
    'method': 'normal',
    'model': 'single',
    'model1_is_divide_variance': True,
    'nb_class': 10
})

# %%
print_accuracy(args)
# Out:
# {'acc_log_file': 'submissions/acc/run.acc',
#  'batch_size': 64,
#  'ckpt_file': 'ckpt/normal_mixup_val_bc/Run01,ModifiedXception,Epoch_33,acc_0.711634.tar',
#  'decay': 1.0,
#  'device': '3',
#  'drop_rate': 0.3,
#  'l2': 0,
#  'method': 'normal',
#  'model': 'single',
#  'model1_is_divide_variance': True,
#  'nb_class': 10}
# 16560it [00:00, 501753.05it/s]
# [LOGGING]: Loading test a of shape:  (4185, 128, 430)
# 16560it [00:00, 204199.59it/s]
# [LOGGING] Normalize using device abc
# 0it [00:00, ?it/s]
# [LOGGING]: Loading test b of shape:  (540, 128, 430)
# [LOGGING] Normalize using device abc
# 16560it [00:00, 485097.21it/s]
# [LOGGING]: Loading test c of shape:  (540, 128, 430)
# [LOGGING] Normalize using device abc
# device_A:
# device_A Validation set average accuracy: 0.767
# device_A Validation set class-wise accuracy:
# airport               : 0.651
# bus                   : 0.786
# metro                 : 0.767
# metro_station         : 0.786
# park                  : 0.899
# public_square         : 0.636
# shopping_mall         : 0.766
# street_pedestrian     : 0.709
# street_traffic        : 0.908
# tram                  : 0.768
# device_B:
# device_B Validation set average accuracy: 0.643
# device_B Validation set class-wise accuracy:
# airport               : 0.296
# bus                   : 0.741
# metro                 : 0.722
# metro_station         : 0.759
# park                  : 0.833
# public_square         : 0.352
# shopping_mall         : 0.722
# street_pedestrian     : 0.444
# street_traffic        : 0.926
# tram                  : 0.630
# device_C:
# device_C Validation set average accuracy: 0.670
# device_C Validation set class-wise accuracy:
# airport               : 0.648
# bus                   : 0.852
# metro                 : 0.556
# metro_station         : 0.667
# park                  : 0.889
# public_square         : 0.296
# shopping_mall         : 0.704
# street_pedestrian     : 0.500
# street_traffic        : 0.926
# tram                  : 0.667
# Average (B, C):
# Average (B, C) Validation set average accuracy: 0.656
# Average (B, C) Validation set class-wise accuracy:
# airport               : 0.472
# bus                   : 0.796
# metro                 : 0.639
# metro_station         : 0.713
# park                  : 0.861
# public_square         : 0.324
# shopping_mall         : 0.713
# street_pedestrian     : 0.472
# street_traffic        : 0.926
# tram                  : 0.648
