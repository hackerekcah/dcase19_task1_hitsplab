# %%
import sys
sys.path.append("..")
# %load_ext autoreload
# %autoreload

# %%
from utils.wrapper import ArgWrapper

# %%
from main_lb_meansub import run
args= ArgWrapper(
    exp='meansub_xcep_mixup', 
    net='ModifiedXception',
    batch_size=32,
    ckpt_prefix='Run01',
    device='5',
    nb_class=10,
    l2=0,
    init_lr=0.001,
    lr_factor=0.5,
    lr_patience=3,
    optimizer='adam',
    plot=True,
    run_epochs=80,
    seed=0,
    decay=1,
    drop_rate=0.3,
    mix_alpha=0.3,
    continue_run=False,
    is_divide_variance=True
)

# %%
run(args)
# Out:
# [CheckPoint:]delete file /data/songhongwei/proj/dcase19_task1_hitsplab/ckpt/meansub_xcep_mixup/Run01,ModifiedXception,Epoch_1,acc_0.415764.tar
# [CheckPoint:]saved model to /data/songhongwei/proj/dcase19_task1_hitsplab/ckpt/meansub_xcep_mixup/Run01,ModifiedXception,Epoch_2,acc_0.538462.tar
