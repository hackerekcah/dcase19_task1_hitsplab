# %%
import sys
sys.path.append("..")
# %load_ext autoreload
# %autoreload

# %%
from utils.wrapper import ArgWrapper

# %%
from main_lb_medfilter import run
args= ArgWrapper(
    exp='medfilter', 
    net='ModifiedXception',
    batch_size=32,
    ckpt_prefix='Run01',
    device='5',
    nb_class=10,
    l2=0,
    init_lr=0.001,
    lr_factor=0.5,
    lr_patience=3,
    optimizer='adam',
    plot=True,
    run_epochs=80,
    seed=0,
    decay=1,
    drop_rate=0.3,
    mix_alpha=-1.0,
    continue_run=False,
    is_divide_variance=False
)

# %%
run(args)
# Out:
# [CheckPoint:]acc not improved on 0.691
# [CheckPoint:]saved model to /data/songhongwei/proj/dcase19_task1_hitsplab/ckpt/medfilter/Run01,ModifiedXception,Epoch_79,acc_0.677683.tar

# %%
args = ArgWrapper({
    'acc_log_file': 'submissions/acc/run.acc',
    'batch_size': 64,
    'ckpt_file': 'ckpt/medfilter/Run01,ModifiedXception,Epoch_10,acc_0.691168.tar',
    'decay': 1.0,
    'device': '5',
    'drop_rate': 0.3,
    'l2': 0,
    'method': 'medfilter',
    'model': 'single',
    'model2_is_divide_variance': False,
    'nb_class': 10
})

# %%
from class_wise_accuracy import print_accuracy
print_accuracy(args)
# Out:
# {'acc_log_file': 'submissions/acc/run.acc',
#  'batch_size': 64,
#  'ckpt_file': 'ckpt/medfilter/Run01,ModifiedXception,Epoch_10,acc_0.691168.tar',
#  'decay': 1.0,
#  'device': '5',
#  'drop_rate': 0.3,
#  'l2': 0,
#  'method': 'medfilter',
#  'model': 'single',
#  'model2_is_divide_variance': False,
#  'nb_class': 10}
# 16560it [00:00, 510887.24it/s]
# [LOGGING]: Loading test a of shape:  (4185, 128, 430)
# 16560it [00:00, 505867.81it/s]
# [LOGGING] Mean subtracted using device abc
# [LOGGING]: Loading test b of shape:  (540, 128, 430)
# 16560it [00:00, 236997.86it/s]
# [LOGGING] Mean subtracted using device abc
# [LOGGING]: Loading test c of shape:  (540, 128, 430)
# [LOGGING] Mean subtracted using device abc
# device_A:
# device_A Validation set average accuracy: 0.718
# device_A Validation set class-wise accuracy:
# airport               : 0.739
# bus                   : 0.798
# metro                 : 0.723
# metro_station         : 0.747
# park                  : 0.834
# public_square         : 0.519
# shopping_mall         : 0.626
# street_pedestrian     : 0.653
# street_traffic        : 0.851
# tram                  : 0.697
# device_B:
# device_B Validation set average accuracy: 0.581
# device_B Validation set class-wise accuracy:
# airport               : 0.537
# bus                   : 0.648
# metro                 : 0.667
# metro_station         : 0.685
# park                  : 0.648
# public_square         : 0.204
# shopping_mall         : 0.519
# street_pedestrian     : 0.463
# street_traffic        : 0.833
# tram                  : 0.611
# device_C:
# device_C Validation set average accuracy: 0.593
# device_C Validation set class-wise accuracy:
# airport               : 0.630
# bus                   : 0.722
# metro                 : 0.537
# metro_station         : 0.574
# park                  : 0.630
# public_square         : 0.259
# shopping_mall         : 0.481
# street_pedestrian     : 0.556
# street_traffic        : 0.870
# tram                  : 0.667
# Average (B, C):
# Average (B, C) Validation set average accuracy: 0.587
# Average (B, C) Validation set class-wise accuracy:
# airport               : 0.583
# bus                   : 0.685
# metro                 : 0.602
# metro_station         : 0.630
# park                  : 0.639
# public_square         : 0.231
# shopping_mall         : 0.500
# street_pedestrian     : 0.509
# street_traffic        : 0.852
# tram                  : 0.639
