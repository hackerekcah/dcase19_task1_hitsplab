# %%
import sys
sys.path.append("..")
# %load_ext autoreload
# %autoreload

# %%
from utils.wrapper import ArgWrapper

# %%
from main_lb import run
args= ArgWrapper(
    exp='normal', 
    net='ModifiedXception',
    batch_size=32,
    ckpt_prefix='Run01',
    device='2',
    nb_class=10,
    l2=0,
    init_lr=0.001,
    lr_factor=0.5,
    lr_patience=3,
    optimizer='adam',
    plot=True,
    run_epochs=80,
    seed=0,
    decay=1,
    drop_rate=0.3,
    mix_alpha=-1.0,
    continue_run=False,
    is_divide_variance=True
)

# %%
run(args)
# Out:
# [CheckPoint:]acc not improved on 0.728
# [CheckPoint:]saved model to /data/songhongwei/proj/dcase19_task1_hitsplab/ckpt/normal/Run01,ModifiedXception,Epoch_79,acc_0.716809.tar

# %%
from class_wise_accuracy import print_accuracy

# %%
args = ArgWrapper({
    'acc_log_file': 'submissions/acc/run.acc',
    'batch_size': 64,
    'ckpt_file': 'ckpt/normal/Run01,ModifiedXception,Epoch_57,acc_0.727635.tar',
    'decay': 1.0,
    'device': '1',
    'drop_rate': 0.3,
    'l2': 0,
    'method': 'normal',
    'model': 'single',
    'model1_is_divide_variance': True,
    'nb_class': 10
})

# %%
print_accuracy(args)
# Out:
# {'acc_log_file': 'submissions/acc/run.acc',
#  'batch_size': 64,
#  'ckpt_file': 'ckpt/normal/Run01,ModifiedXception,Epoch_57,acc_0.727635.tar',
#  'decay': 1.0,
#  'device': '1',
#  'drop_rate': 0.3,
#  'l2': 0,
#  'method': 'normal',
#  'model': 'single',
#  'model1_is_divide_variance': True,
#  'nb_class': 10}
# 16560it [00:00, 489045.56it/s]
# [LOGGING]: Loading test a of shape:  (4185, 128, 430)
# 16560it [00:00, 500870.20it/s]
# [LOGGING] Normalize using device abc
# [LOGGING]: Loading test b of shape:  (540, 128, 430)
# 16560it [00:00, 517518.23it/s]
# [LOGGING] Normalize using device abc
# [LOGGING]: Loading test c of shape:  (540, 128, 430)
# [LOGGING] Normalize using device abc
# device_A:
# device_A Validation set average accuracy: 0.764
# device_A Validation set class-wise accuracy:
# airport               : 0.779
# bus                   : 0.853
# metro                 : 0.774
# metro_station         : 0.798
# park                  : 0.850
# public_square         : 0.612
# shopping_mall         : 0.698
# street_pedestrian     : 0.671
# street_traffic        : 0.888
# tram                  : 0.722
# device_B:
# device_B Validation set average accuracy: 0.552
# device_B Validation set class-wise accuracy:
# airport               : 0.333
# bus                   : 0.537
# metro                 : 0.759
# metro_station         : 0.630
# park                  : 0.815
# public_square         : 0.111
# shopping_mall         : 0.685
# street_pedestrian     : 0.333
# street_traffic        : 0.907
# tram                  : 0.407
# device_C:
# device_C Validation set average accuracy: 0.622
# device_C Validation set class-wise accuracy:
# airport               : 0.611
# bus                   : 0.852
# metro                 : 0.759
# metro_station         : 0.537
# park                  : 0.944
# public_square         : 0.204
# shopping_mall         : 0.574
# street_pedestrian     : 0.444
# street_traffic        : 0.907
# tram                  : 0.389
# Average (B, C):
# Average (B, C) Validation set average accuracy: 0.587
# Average (B, C) Validation set class-wise accuracy:
# airport               : 0.472
# bus                   : 0.694
# metro                 : 0.759
# metro_station         : 0.583
# park                  : 0.880
# public_square         : 0.157
# shopping_mall         : 0.630
# street_pedestrian     : 0.389
# street_traffic        : 0.907
# tram                  : 0.398
