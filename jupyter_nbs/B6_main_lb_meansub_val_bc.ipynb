# %%
import sys
sys.path.append("..")
# %load_ext autoreload
# %autoreload

# %%
from utils.wrapper import ArgWrapper

# %%
from main_lb_meansub_val_bc import run
args= ArgWrapper(
    exp='meansub_mixup_val_bc', 
    net='ModifiedXception',
    batch_size=32,
    ckpt_prefix='Run01',
    device='0',
    nb_class=10,
    l2=0,
    init_lr=0.001,
    lr_factor=0.5,
    lr_patience=3,
    optimizer='adam',
    plot=True,
    run_epochs=80,
    seed=0,
    decay=1,
    drop_rate=0.3,
    mix_alpha=0.3,
    continue_run=False,
    is_divide_variance=False
)

# %%
run(args)
# Out:
# [CheckPoint:]acc not improved on 0.685
# [CheckPoint:]saved model to /data/songhongwei/proj/dcase19_task1_hitsplab/ckpt/meansub_mixup_val_bc/Run01,ModifiedXception,Epoch_79,acc_0.680048.tar

# %%
args = ArgWrapper({
    'acc_log_file': 'submissions/acc/run.acc',
    'batch_size': 64,
    'ckpt_file': 'ckpt/meansub_mixup_val_bc/Run01,ModifiedXception,Epoch_62,acc_0.684946.tar',
    'decay': 1.0,
    'device': '0',
    'drop_rate': 0.3,
    'l2': 0,
    'method': 'meansub',
    'model': 'single',
    'model3_is_divide_variance': False,
    'nb_class': 10
})

# %%
from class_wise_accuracy import print_accuracy
print_accuracy(args)
# Out:
# {'acc_log_file': 'submissions/acc/run.acc',
#  'batch_size': 64,
#  'ckpt_file': 'ckpt/meansub_mixup_val_bc/Run01,ModifiedXception,Epoch_62,acc_0.684946.tar',
#  'decay': 1.0,
#  'device': '0',
#  'drop_rate': 0.3,
#  'l2': 0,
#  'method': 'meansub',
#  'model': 'single',
#  'model3_is_divide_variance': False,
#  'nb_class': 10}
# 16560it [00:00, 231108.05it/s]
# [LOGGING]: Loading test a of shape:  (4185, 128, 430)
# 16560it [00:00, 520570.76it/s]
# [LOGGING] Mean subtracted using device abc
# [LOGGING]: Loading test b of shape:  (540, 128, 430)
# 16560it [00:00, 274305.32it/s]
# [LOGGING] Mean subtracted using device abc
# [LOGGING]: Loading test c of shape:  (540, 128, 430)
# [LOGGING] Mean subtracted using device abc
# device_A:
# device_A Validation set average accuracy: 0.696
# device_A Validation set class-wise accuracy:
# airport               : 0.556
# bus                   : 0.822
# metro                 : 0.700
# metro_station         : 0.657
# park                  : 0.852
# public_square         : 0.545
# shopping_mall         : 0.642
# street_pedestrian     : 0.590
# street_traffic        : 0.908
# tram                  : 0.704
# device_B:
# device_B Validation set average accuracy: 0.672
# device_B Validation set class-wise accuracy:
# airport               : 0.537
# bus                   : 0.815
# metro                 : 0.704
# metro_station         : 0.685
# park                  : 0.741
# public_square         : 0.352
# shopping_mall         : 0.815
# street_pedestrian     : 0.389
# street_traffic        : 0.889
# tram                  : 0.796
# device_C:
# device_C Validation set average accuracy: 0.676
# device_C Validation set class-wise accuracy:
# airport               : 0.500
# bus                   : 0.833
# metro                 : 0.741
# metro_station         : 0.759
# park                  : 0.574
# public_square         : 0.352
# shopping_mall         : 0.778
# street_pedestrian     : 0.667
# street_traffic        : 0.944
# tram                  : 0.611
# Average (B, C):
# Average (B, C) Validation set average accuracy: 0.674
# Average (B, C) Validation set class-wise accuracy:
# airport               : 0.519
# bus                   : 0.824
# metro                 : 0.722
# metro_station         : 0.722
# park                  : 0.657
# public_square         : 0.352
# shopping_mall         : 0.796
# street_pedestrian     : 0.528
# street_traffic        : 0.917
# tram                  : 0.704
