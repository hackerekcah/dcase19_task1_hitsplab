# %%
import sys
sys.path.append("..")
# %load_ext autoreload
# %autoreload

# %%
from utils.wrapper import ArgWrapper

# %%
from main_lb import run
args= ArgWrapper(
    exp='normal_mixup', 
    net='ModifiedXception',
    batch_size=32,
    ckpt_prefix='Run01',
    device='3',
    nb_class=10,
    l2=0,
    init_lr=0.001,
    lr_factor=0.5,
    lr_patience=3,
    optimizer='adam',
    plot=True,
    run_epochs=80,
    seed=0,
    decay=1,
    drop_rate=0.3,
    mix_alpha=0.3,
    continue_run=False,
    is_divide_variance=True
)

# %%
run(args)
# Out:
# [CheckPoint:]acc not improved on 0.749
# [CheckPoint:]saved model to /data/songhongwei/proj/dcase19_task1_hitsplab/ckpt/normal_mixup/Run01,ModifiedXception,Epoch_79,acc_0.746439.tar

# %%
from class_wise_accuracy import print_accuracy

# %%
args = ArgWrapper({
    'acc_log_file': 'submissions/acc/run.acc',
    'batch_size': 64,
    'ckpt_file': 'ckpt/normal_mixup/Run01,ModifiedXception,Epoch_68,acc_0.748528.tar',
    'decay': 1.0,
    'device': '3',
    'drop_rate': 0.3,
    'l2': 0,
    'method': 'normal',
    'model': 'single',
    'model1_is_divide_variance': True,
    'nb_class': 10
})

# %%
print_accuracy(args)
# Out:
# {'acc_log_file': 'submissions/acc/run.acc',
#  'batch_size': 64,
#  'ckpt_file': 'ckpt/normal_mixup/Run01,ModifiedXception,Epoch_68,acc_0.748528.tar',
#  'decay': 1.0,
#  'device': '3',
#  'drop_rate': 0.3,
#  'l2': 0,
#  'method': 'normal',
#  'model': 'single',
#  'model1_is_divide_variance': True,
#  'nb_class': 10}
# 16560it [00:00, 218390.14it/s]
# [LOGGING]: Loading test a of shape:  (4185, 128, 430)
# 16560it [00:00, 238251.42it/s]
# [LOGGING] Normalize using device abc
# [LOGGING]: Loading test b of shape:  (540, 128, 430)
# 16560it [00:00, 392646.95it/s]
# [LOGGING] Normalize using device abc
# [LOGGING]: Loading test c of shape:  (540, 128, 430)
# [LOGGING] Normalize using device abc
# device_A:
# device_A Validation set average accuracy: 0.778
# device_A Validation set class-wise accuracy:
# airport               : 0.746
# bus                   : 0.841
# metro                 : 0.746
# metro_station         : 0.821
# park                  : 0.920
# public_square         : 0.589
# shopping_mall         : 0.673
# street_pedestrian     : 0.751
# street_traffic        : 0.925
# tram                  : 0.782
# device_B:
# device_B Validation set average accuracy: 0.606
# device_B Validation set class-wise accuracy:
# airport               : 0.389
# bus                   : 0.741
# metro                 : 0.537
# metro_station         : 0.685
# park                  : 0.741
# public_square         : 0.167
# shopping_mall         : 0.722
# street_pedestrian     : 0.574
# street_traffic        : 0.926
# tram                  : 0.574
# device_C:
# device_C Validation set average accuracy: 0.659
# device_C Validation set class-wise accuracy:
# airport               : 0.574
# bus                   : 0.815
# metro                 : 0.556
# metro_station         : 0.630
# park                  : 0.926
# public_square         : 0.167
# shopping_mall         : 0.778
# street_pedestrian     : 0.648
# street_traffic        : 0.926
# tram                  : 0.574
# Average (B, C):
# Average (B, C) Validation set average accuracy: 0.632
# Average (B, C) Validation set class-wise accuracy:
# airport               : 0.481
# bus                   : 0.778
# metro                 : 0.546
# metro_station         : 0.657
# park                  : 0.833
# public_square         : 0.167
# shopping_mall         : 0.750
# street_pedestrian     : 0.611
# street_traffic        : 0.926
# tram                  : 0.574
