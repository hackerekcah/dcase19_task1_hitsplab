# %%
import sys
sys.path.append("..")
# %load_ext autoreload
# %autoreload

# %%
from utils.wrapper import ArgWrapper

# %%
from main_lb_val_bc import run
args= ArgWrapper(
    exp='normal_val_bc', 
    net='ModifiedXception',
    batch_size=32,
    ckpt_prefix='Run01',
    device='2',
    nb_class=10,
    l2=0,
    init_lr=0.001,
    lr_factor=0.5,
    lr_patience=3,
    optimizer='adam',
    plot=True,
    run_epochs=80,
    seed=0,
    decay=1,
    drop_rate=0.3,
    mix_alpha=-1.0,
    continue_run=False,
    is_divide_variance=True
)

# %%
run(args)
# Out:
# [CheckPoint:]acc not improved on 0.672
# [CheckPoint:]saved model to /data/songhongwei/proj/dcase19_task1_hitsplab/ckpt/normal_val_bc/Run01,ModifiedXception,Epoch_79,acc_0.664217.tar

# %%
from class_wise_accuracy import print_accuracy

# %%
args = ArgWrapper({
    'acc_log_file': 'submissions/acc/run.acc',
    'batch_size': 64,
    'ckpt_file': 'ckpt/normal_val_bc/Run01,ModifiedXception,Epoch_43,acc_0.671714.tar',
    'decay': 1.0,
    'device': '2',
    'drop_rate': 0.3,
    'l2': 0,
    'method': 'normal',
    'model': 'single',
    'model1_is_divide_variance': True,
    'nb_class': 10
})

# %%
print_accuracy(args)
# Out:
# {'acc_log_file': 'submissions/acc/run.acc',
#  'batch_size': 64,
#  'ckpt_file': 'ckpt/normal_val_bc/Run01,ModifiedXception,Epoch_43,acc_0.671714.tar',
#  'decay': 1.0,
#  'device': '2',
#  'drop_rate': 0.3,
#  'l2': 0,
#  'method': 'normal',
#  'model': 'single',
#  'model1_is_divide_variance': True,
#  'nb_class': 10}
# 16560it [00:00, 262124.21it/s]
# [LOGGING]: Loading test a of shape:  (4185, 128, 430)
# 16560it [00:00, 405649.11it/s]
# [LOGGING] Normalize using device abc
# 0it [00:00, ?it/s]
# [LOGGING]: Loading test b of shape:  (540, 128, 430)
# [LOGGING] Normalize using device abc
# 16560it [00:00, 505323.13it/s]
# [LOGGING]: Loading test c of shape:  (540, 128, 430)
# [LOGGING] Normalize using device abc
# device_A:
# device_A Validation set average accuracy: 0.760
# device_A Validation set class-wise accuracy:
# airport               : 0.736
# bus                   : 0.810
# metro                 : 0.700
# metro_station         : 0.786
# park                  : 0.858
# ...
