# %%
import sys
sys.path.append("..")
# %load_ext autoreload
# %autoreload

# %%
from utils.wrapper import ArgWrapper

# %%
from main_lb_medfilter import run
args= ArgWrapper(
    exp='medfilter_mixup', 
    net='ModifiedXception',
    batch_size=32,
    ckpt_prefix='Run01',
    device='4',
    nb_class=10,
    l2=0,
    init_lr=0.001,
    lr_factor=0.5,
    lr_patience=3,
    optimizer='adam',
    plot=True,
    run_epochs=80,
    seed=0,
    decay=1,
    drop_rate=0.3,
    mix_alpha=0.3,
    continue_run=False,
    is_divide_variance=False
)

# %%
run(args)
# Out:
# [CheckPoint:]acc not improved on 0.710
# [CheckPoint:]saved model to /data/songhongwei/proj/dcase19_task1_hitsplab/ckpt/medfilter_mixup/Run01,ModifiedXception,Epoch_79,acc_0.703894.tar

# %%
args = ArgWrapper({
    'acc_log_file': 'submissions/acc/run.acc',
    'batch_size': 64,
    'ckpt_file': 'ckpt/medfilter_mixup/Run01,ModifiedXception,Epoch_34,acc_0.710351.tar',
    'decay': 1.0,
    'device': '4',
    'drop_rate': 0.3,
    'l2': 0,
    'method': 'medfilter',
    'model': 'single',
    'model2_is_divide_variance': False,
    'nb_class': 10
})

# %%
from class_wise_accuracy import print_accuracy
print_accuracy(args)
# Out:
# {'acc_log_file': 'submissions/acc/run.acc',
#  'batch_size': 64,
#  'ckpt_file': 'ckpt/medfilter_mixup/Run01,ModifiedXception,Epoch_34,acc_0.710351.tar',
#  'decay': 1.0,
#  'device': '4',
#  'drop_rate': 0.3,
#  'l2': 0,
#  'method': 'medfilter',
#  'model': 'single',
#  'model2_is_divide_variance': False,
#  'nb_class': 10}
# 16560it [00:00, 479048.18it/s]
# [LOGGING]: Loading test a of shape:  (4185, 128, 430)
# 16560it [00:00, 251421.39it/s]
# [LOGGING] Mean subtracted using device abc
# 16560it [00:00, 387425.67it/s]
# [LOGGING]: Loading test b of shape:  (540, 128, 430)
# [LOGGING] Mean subtracted using device abc
# [LOGGING]: Loading test c of shape:  (540, 128, 430)
# [LOGGING] Mean subtracted using device abc
# device_A:
# device_A Validation set average accuracy: 0.734
# device_A Validation set class-wise accuracy:
# airport               : 0.762
# bus                   : 0.822
# metro                 : 0.711
# metro_station         : 0.694
# park                  : 0.894
# public_square         : 0.558
# shopping_mall         : 0.633
# street_pedestrian     : 0.657
# street_traffic        : 0.915
# tram                  : 0.709
# device_B:
# device_B Validation set average accuracy: 0.606
# device_B Validation set class-wise accuracy:
# airport               : 0.556
# bus                   : 0.667
# metro                 : 0.722
# metro_station         : 0.667
# park                  : 0.704
# public_square         : 0.148
# shopping_mall         : 0.667
# street_pedestrian     : 0.500
# street_traffic        : 0.889
# tram                  : 0.537
# device_C:
# device_C Validation set average accuracy: 0.633
# device_C Validation set class-wise accuracy:
# airport               : 0.667
# bus                   : 0.759
# metro                 : 0.593
# metro_station         : 0.630
# park                  : 0.815
# public_square         : 0.093
# shopping_mall         : 0.722
# street_pedestrian     : 0.556
# street_traffic        : 0.889
# tram                  : 0.611
# Average (B, C):
# Average (B, C) Validation set average accuracy: 0.619
# Average (B, C) Validation set class-wise accuracy:
# airport               : 0.611
# bus                   : 0.713
# metro                 : 0.657
# metro_station         : 0.648
# park                  : 0.759
# public_square         : 0.120
# shopping_mall         : 0.694
# street_pedestrian     : 0.528
# street_traffic        : 0.889
# tram                  : 0.574
