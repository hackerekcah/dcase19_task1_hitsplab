# %%
import sys
sys.path.append("..")
# %load_ext autoreload
# %autoreload

# %%
from utils.wrapper import ArgWrapper

# %%
from main_lb_unpretrained_val_bc import run
args= ArgWrapper(
    exp='unpretrained_val_bc', 
    net='ModifiedXception',
    batch_size=32,
    ckpt_prefix='Run01',
    device='2',
    nb_class=10,
    l2=0,
    init_lr=0.001,
    lr_factor=0.5,
    lr_patience=3,
    optimizer='adam',
    plot=True,
    run_epochs=80,
    seed=0,
    decay=1,
    drop_rate=0.3,
    mix_alpha=-1.0,
    continue_run=False,
    is_divide_variance=True
)

# %%
run(args)
# Out:
# [CheckPoint:]acc not improved on 0.600
# [CheckPoint:]saved model to /data/songhongwei/proj/dcase19_task1_hitsplab/ckpt/unpretrained_val_bc/Run01,ModifiedXception,Epoch_79,acc_0.593668.tar

# %%
args = ArgWrapper({
    'acc_log_file': 'submissions/acc/run.acc',
    'batch_size': 64,
    'ckpt_file': 'ckpt/unpretrained_val_bc/Run01,ModifiedXception,Epoch_69,acc_0.599866.tar',
    'decay': 1.0,
    'device': '2',
    'drop_rate': 0.3,
    'l2': 0,
    'method': 'normal',
    'model': 'single',
    'model1_is_divide_variance': True,
    'nb_class': 10
})

# %%
from class_wise_accuracy import print_accuracy
print_accuracy(args)
# Out:
# {'acc_log_file': 'submissions/acc/run.acc',
#  'batch_size': 64,
#  'ckpt_file': 'ckpt/unpretrained_val_bc/Run01,ModifiedXception,Epoch_69,acc_0.599866.tar',
#  'decay': 1.0,
#  'device': '2',
#  'drop_rate': 0.3,
#  'l2': 0,
#  'method': 'normal',
#  'model': 'single',
#  'model1_is_divide_variance': True,
#  'nb_class': 10}
# 16560it [00:00, 210039.26it/s]
# [LOGGING]: Loading test a of shape:  (4185, 128, 430)
# 16560it [00:00, 503228.96it/s]
# [LOGGING] Normalize using device abc
# [LOGGING]: Loading test b of shape:  (540, 128, 430)
# 16560it [00:00, 513975.89it/s]
# [LOGGING] Normalize using device abc
# [LOGGING]: Loading test c of shape:  (540, 128, 430)
# [LOGGING] Normalize using device abc
# device_A:
# device_A Validation set average accuracy: 0.688
# device_A Validation set class-wise accuracy:
# airport               : 0.694
# bus                   : 0.655
# metro                 : 0.626
# metro_station         : 0.745
# park                  : 0.821
# public_square         : 0.481
# shopping_mall         : 0.624
# street_pedestrian     : 0.648
# street_traffic        : 0.888
# tram                  : 0.702
# device_B:
# device_B Validation set average accuracy: 0.480
# device_B Validation set class-wise accuracy:
# airport               : 0.241
# bus                   : 0.426
# metro                 : 0.389
# metro_station         : 0.685
# park                  : 0.833
# public_square         : 0.130
# shopping_mall         : 0.537
# street_pedestrian     : 0.389
# street_traffic        : 0.852
# tram                  : 0.315
# device_C:
# device_C Validation set average accuracy: 0.544
# device_C Validation set class-wise accuracy:
# airport               : 0.574
# bus                   : 0.852
# metro                 : 0.407
# metro_station         : 0.556
# park                  : 0.778
# public_square         : 0.241
# shopping_mall         : 0.481
# street_pedestrian     : 0.352
# street_traffic        : 0.926
# tram                  : 0.278
# Average (B, C):
# Average (B, C) Validation set average accuracy: 0.512
# Average (B, C) Validation set class-wise accuracy:
# airport               : 0.407
# bus                   : 0.639
# metro                 : 0.398
# metro_station         : 0.620
# park                  : 0.806
# public_square         : 0.185
# shopping_mall         : 0.509
# street_pedestrian     : 0.370
# street_traffic        : 0.889
# tram                  : 0.296
